# %% [markdown]
# <a href="https://colab.research.google.com/github/ichbinjuwilke/bootcamp_Unimed/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.read_excel("Aracaju.xlsx")
df2 = pd.read_excel("Fortaleza.xlsx")
df3 = pd.read_excel("Natal.xlsx")
df4 = pd.read_excel("Recife.xlsx")
df5 = pd.read_excel("Salvador.xlsx")

# %%
df = pd.concat([df1, df2, df3, df4, df5])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df["LojaID"] = df["LojaID"].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df["Vendas"].fillna(df["Vendas"].mean(), inplace=True)

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00   1520     1
# 1  Aracaju 2018-01-01   14.21   1522     6
# 2  Aracaju 2018-01-01   71.55   1520     1
# 3  Aracaju 2018-01-01    3.01   1521     7
# 4  Aracaju 2018-01-01   24.51   1522     8

# %%
df["Vendas"].fillna(0, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df["Receita"]= df["Vendas"].mul(df["Qtde"])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00    1520     1   142.00
# 1  Aracaju 2018-01-01   14.21    1522     6    85.26
# 2  Aracaju 2018-01-01   71.55    1520     1    71.55
# 3  Aracaju 2018-01-01    3.01    1521     7    21.07
# 4  Aracaju 2018-01-01   24.51    1522     8   196.08

# %%
df.describe()
# Out:
#            Vendas       LojaID        Qtde      Receita
# count  894.000000   894.000000  894.000000   894.000000
# mean   122.611801  1074.844519    3.261745   387.497740
# std    166.818723   191.360735    2.096964   575.518524
# min      3.010000   852.000000    1.000000     3.340000
# 25%     22.380000   983.000000    2.000000    63.540000
# 50%     44.000000  1035.000000    3.000000   155.560000
# 75%    160.925000  1037.000000    4.000000   458.310000
# max    886.000000  1523.000000   10.000000  3544.000000

# %%
df["Receita"].max()
# Out:
# 3544.0

# %%
df["Receita"].min()
# Out:
# 3.34

# %%
df.nlargest(3,"Receita") #top 3
# Out:
#    Cidade       Data  Vendas  LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0     853     4   3544.0
# 51  Natal 2018-01-21   859.0     852     4   3436.0
# 55  Natal 2019-01-08   859.0     854     4   3436.0

# %%
df.nsmallest(3,"Receita")
# Out:
#       Cidade       Data  Vendas  LojaID  Qtde  Receita
# 118  Aracaju 2018-01-01    3.34    1522     1     3.34
# 65    Recife 2019-01-01    4.01     981     1     4.01
# 92     Natal 2019-01-02    4.57    1035     1     4.57

# %%
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
df.sort_values("Receita", ascending=False). head(10) #ordena os dados
# Out:
#    Cidade       Data  Vendas  LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0     853     4   3544.0
# 55  Natal 2019-01-08   859.0     854     4   3436.0
# 51  Natal 2018-01-21   859.0     852     4   3436.0
# 30  Natal 2018-10-02   856.0     853     4   3424.0
# 41  Natal 2018-05-20   835.0     852     4   3340.0
# 38  Natal 2018-02-25   828.0     852     4   3312.0
# 10  Natal 2018-10-27   828.0     852     4   3312.0
# 69  Natal 2019-03-24   817.0     852     4   3268.0
# 62  Natal 2018-02-10   793.0     854     4   3172.0
# 52  Natal 2018-04-27   778.0     854     4   3112.0

# %%
df.dtypes
# Out:
# Cidade             object
# Data       datetime64[ns]
# Vendas            float64
# LojaID              int64
# Qtde                int64
# Receita           float64
# dtype: object

# %%
df["Data"] = df["Data"].astype("int64")

# %%
df.dtypes
# Out:
# Cidade      object
# Data         int64
# Vendas     float64
# LojaID       int64
# Qtde         int64
# Receita    float64
# dtype: object

# %%
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Cidade             object
# Data       datetime64[ns]
# Vendas            float64
# LojaID              int64
# Qtde                int64
# Receita           float64
# dtype: object

# %%
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
df["Ano_venda"]= df["Data"].dt.year

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_venda
# 0  Aracaju 2018-01-01  142.00    1520     1   142.00       2018
# 1  Aracaju 2018-01-01   14.21    1522     6    85.26       2018
# 2  Aracaju 2018-01-01   71.55    1520     1    71.55       2018
# 3  Aracaju 2018-01-01    3.01    1521     7    21.07       2018
# 4  Aracaju 2018-01-01   24.51    1522     8   196.08       2018

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_venda
# 189   Salvador 2019-01-02  139.73    1037     2   279.46       2019
# 165   Salvador 2019-01-02   11.54    1037     1    11.54       2019
# 104  Fortaleza 2019-01-01   40.50    1005     2    81.00       2019
# 40   Fortaleza 2019-02-13   19.13    1002     4    76.52       2019
# 222      Natal 2019-01-02   43.96    1037     1    43.96       2019

# %%
df["Mês_venda"] = df["Data"].dt.month

# %%
df["Dia_venda"] = df["Data"].dt.day

# %%
df.sample(10)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_venda  Mês_venda  \
# 72    Aracaju 2018-01-01  168.95    1523     7  1182.65       2018          1
# 11      Natal 2019-02-09  564.00     853     3  1692.00       2019          2
# 14      Natal 2018-06-03  660.00     853     3  1980.00       2018          6
# 107     Natal 2019-01-02   14.70    1035     1    14.70       2019          1
# 45   Salvador 2019-01-01  175.25    1035     3   525.75       2019          1
# 140     Natal 2019-01-02   20.79    1036     2    41.58       2019          1
# 65   Salvador 2019-01-01    3.39    1034     2     6.78       2019          1
# 206  Salvador 2019-01-02  151.45    1036     2   302.90       2019          1
# 34      Natal 2019-01-07  484.00     852     2   968.00       2019          1
# 59      Natal 2018-01-15  369.00     853     2   738.00       2018          1
#
#      Dia_venda
# 72           1
# 11           9
# 14           3
# 107          2
# 45           1
# ...

# %%
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
df["Data"].max()
# Out:
# Timestamp('2019-04-05 00:00:00')

# %%
df["Diferença_dias"] = df["Data"] - df["Data"].min()

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_venda  Mês_venda  \
# 14      Natal 2018-06-03  660.00     853     3  1980.00       2018          6
# 39   Salvador 2019-01-01  165.95    1036     3   497.85       2019          1
# 18      Natal 2019-03-14  581.00     853     3  1743.00       2019          3
# 106  Salvador 2019-01-01  149.19    1035     2   298.38       2019          1
# 180  Salvador 2019-01-02  116.63    1035     2   233.26       2019          1
#
#      Dia_venda Diferença_dias
# 14           3       153 days
# 39           1       365 days
# 18          14       437 days
# 106          1       365 days
# 180          2       366 days

# %%
df["Trimestre_venda"]= df["Data"].dt.quarter

# %%
df.sample(10)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_venda  \
# 228      Natal 2019-01-02    6.87    1037     3    20.61       2019
# 98      Recife 2019-01-01  137.34     981     8  1098.72       2019
# 221      Natal 2019-01-02  142.23    1035     2   284.46       2019
# 123  Fortaleza 2019-03-02   20.22     981     6   121.32       2019
# 122  Fortaleza 2019-03-02  235.06     983     3   705.18       2019
# 199   Salvador 2019-01-02  153.87    1036     3   461.61       2019
# 14       Natal 2018-06-03  660.00     853     3  1980.00       2018
# 135      Natal 2019-01-02    9.95    1037     3    29.85       2019
# 109   Salvador 2019-03-02  124.37    1035     1   124.37       2019
# 102    Aracaju 2018-01-01    7.29    1523     1     7.29       2018
#
#      Mês_venda  Dia_venda Diferença_dias  Trimestre_venda
# 228          1          2       366 days                1
# 98           1          1       365 days                1
# ...

# %%
df= df.rename(columns={"Semestre_venda": "Trimestre_venda"})

# %%
#filtrar
vendas_março_19 = df.loc[(df["Data"].dt.year == 2019) & (df["Data"].dt.month == 3)]

# %%
vendas_março_19.head()
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_venda  \
# 108  Fortaleza 2019-03-02  152.89     981     4   611.56       2019
# 109  Fortaleza 2019-03-02   18.90     982     6   113.40       2019
# 110  Fortaleza 2019-03-02   51.98     983     6   311.88       2019
# 111  Fortaleza 2019-03-02    8.00     981     3    24.00       2019
# 112  Fortaleza 2019-03-02  133.59     982     1   133.59       2019
#
#      Mês_venda  Dia_venda Diferença_dias  Trimestre_venda
# 108          3          2       425 days                1
# 109          3          2       425 days                1
# 110          3          2       425 days                1
# 111          3          2       425 days                1
# 112          3          2       425 days                1

# %%
vendas_março_19.describe()
# Out:
#            Vendas       LojaID        Qtde      Receita  Ano_venda  Mês_venda  \
# count  121.000000   121.000000  121.000000   121.000000      121.0      121.0
# mean   159.679587   976.834711    3.801653   524.090992     2019.0        3.0
# std    216.946250    58.423789    2.064057   682.688314        0.0        0.0
# min      8.000000   852.000000    1.000000     9.080000     2019.0        3.0
# 25%     25.000000   981.000000    2.000000   102.690000     2019.0        3.0
# 50%     51.990000   982.000000    3.000000   169.010000     2019.0        3.0
# 75%    182.750000  1034.000000    5.000000   834.420000     2019.0        3.0
# max    886.000000  1037.000000    8.000000  3544.000000     2019.0        3.0
#
#         Dia_venda               Diferença_dias  Trimestre_venda
# count  121.000000                          121            121.0
# mean     4.396694  427 days 09:31:14.380165288              1.0
# std      6.593531    6 days 14:14:41.108534842              0.0
# ...

# %%
df["LojaID"].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
df["LojaID"].value_counts(ascending=False).plot.bar()

# %%
df["LojaID"].value_counts(ascending=True).plot.barh();

# %%
df.groupby(df["Data"].dt.year)["Receita"].sum().plot.pie();

# %%
df["Cidade"].value_counts()
# Out:
# Natal        240
# Salvador     240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
df["Cidade"].value_counts().plot.pie()

# %%
import matplotlib.pyplot as plt
df["Cidade"].value_counts().plot.bar(title="Total vendas por Cidade")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas");

# %%
#Alterar cor
df["Cidade"].value_counts().plot.bar(title="Total de vendas por Cidade", color ="green")
plt.xlabel("Cidade")
plt.ylabel("Total vendas");

# %%
#Alterando o estilo
plt.style.use("ggplot")

# %%
df.groupby(df["Mês_venda"])["Qtde"].sum().plot(title= "Total produtos vendidos por mês")
plt.xlabel("Mês")
plt.ylabel("Total produtos vendidos");
plt.legend()

# %%
df.groupby(["Mês_venda"])["Qtde"].sum()
# Out:
# Mês_venda
# 1     2208
# 2      144
# 3      467
# 4       23
# 5       17
# 6       13
# 7       13
# 8        2
# 9       10
# 10      14
# 11       2
# 12       3
# Name: Qtde, dtype: int64

# %%
df_2019= df[df["Ano_venda"]== 2019]

# %%
df_2019.head()
# Out:
#      Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_venda  Mês_venda  \
# 7   Aracaju 2019-01-01  172.22    1522     6  1033.32       2019          1
# 8   Aracaju 2019-01-01   12.16    1523     1    12.16       2019          1
# 9   Aracaju 2019-01-01  149.36    1523     3   448.08       2019          1
# 10  Aracaju 2019-01-01   42.34    1522     6   254.04       2019          1
# 11  Aracaju 2019-01-01  161.53    1520     4   646.12       2019          1
#
#     Dia_venda Diferença_dias  Trimestre_venda
# 7           1       365 days                1
# 8           1       365 days                1
# 9           1       365 days                1
# 10          1       365 days                1
# 11          1       365 days                1

# %%
df_2019.groupby(df_2019["Mês_venda"])["Qtde"].sum()
# Out:
# Mês_venda
# 1    1541
# 2     128
# 3     460
# 4      12
# Name: Qtde, dtype: int64

# %%
df_2019.groupby(df_2019["Mês_venda"])["Qtde"].sum().plot(marker = "o")
plt.xlabel("Mês")
plt.ylabel("Total Produtos Vendidos")
plt.legend();

# %%
plt.hist(df["Qtde"], color = "orangered");

# %%
plt.scatter(x=df_2019["Dia_venda"], y= df_2019["Receita"]);

# %%
df_2019.groupby(df_2019["Mês_venda"])["Qtde"].sum().plot(marker="o")
plt.title("Quantidade de produtos vendidos x mês")
plt.xlabel("Mês")
plt.ylabel("Total Produtos vendidos")
plt.legend()
plt.savefig("grafico QTDE x MES.png")
